# %%
nome = "Gonçalo"  # criar uma var

# %%
nome
print(nome)
# Out:
# Gonçalo

# %%
idade2: int = 12
nome2: str = "Gonçalo"
altura2: float = 1.2
aprovado2: bool = True

# %%
print(idade2)
idade2 = "Dez"
# Out:
# Dez

# %%
print(idade2)
# Out:
# Dez
