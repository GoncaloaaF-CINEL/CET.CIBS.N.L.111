# %%
nome = "Gonçalo"  # criar uma var

# %%
nome
print(nome)
# Out:
# Gonçalo

# %%
idade2: int = 12
nome2: str = "Gonçalo"
altura2: float = 1.2
aprovado2: bool = True

# %%
print(idade2)
idade2 = "Dez"
# Out:
# Dez

# %%
print(idade2)
# Out:
# Dez

# %% [markdown]
# # sessão 3

# %%
num1 = input("Digite o 1º numero: ")

# %%
type(num1)
# Out:
# str

# %%
num = 2.1251

# %%
print(num.__floor__())
# Out:
# 2

# %%
print(num.__ceil__())
# Out:
# 3

# %%
num.__round__(1)
# Out:
# 2.1

# %%
n = 3
print(f"{n:.2f}")
# Out:
# 3.00

# %%
out = format(n, ".2f")
print(out)
# Out:
# 3.00

# %%
out = n.__format__(".2f")
print(out)
# Out:
# 3.00
